# %%
import logging
import gensim
from gensim.models import word2vec

# %%
wordVec = gensim.models.KeyedVectors.load_word2vec_format("word2Vec.bin", binary=True)

# %%
wordVec.vocab
# Out:
# {'winery': <gensim.models.keyedvectors.Vocab at 0x7fb6121e5fd0>,
#  'samei': <gensim.models.keyedvectors.Vocab at 0x7fb6122672b0>,
#  'teachers': <gensim.models.keyedvectors.Vocab at 0x7fb612a9b550>,
#  'farrah': <gensim.models.keyedvectors.Vocab at 0x7fb6129ca748>,
#  'whatsoeverthe': <gensim.models.keyedvectors.Vocab at 0x7fb61215d390>,
#  'histories': <gensim.models.keyedvectors.Vocab at 0x7fb612760748>,
#  'tumbleweeds': <gensim.models.keyedvectors.Vocab at 0x7fb611d33080>,
#  'empathise': <gensim.models.keyedvectors.Vocab at 0x7fb612869f28>,
#  'segues': <gensim.models.keyedvectors.Vocab at 0x7fb612681f60>,
#  'veronika': <gensim.models.keyedvectors.Vocab at 0x7fb61265e080>,
#  'followthe': <gensim.models.keyedvectors.Vocab at 0x7fb611bd0a20>,
#  'whisky': <gensim.models.keyedvectors.Vocab at 0x7fb61231e278>,
#  'oddity': <gensim.models.keyedvectors.Vocab at 0x7fb6128d4978>,
#  'tilo': <gensim.models.keyedvectors.Vocab at 0x7fb611e20ba8>,
#  'versed': <gensim.models.keyedvectors.Vocab at 0x7fb6124e80f0>,
#  'characters': <gensim.models.keyedvectors.Vocab at 0x7fb61585da20>,
#  'sprawling': <gensim.models.keyedvectors.Vocab at 0x7fb6127c9eb8>,
#  'undeniably': <gensim.models.keyedvectors.Vocab at 0x7fb6129b1518>,
#  'kgb': <gensim.models.keyedvectors.Vocab at 0x7fb6126aca20>,
#  'taunt': <gensim.models.keyedvectors.Vocab at 0x7fb612594b38>,
#  'macrae': <gensim.models.keyedvectors.Vocab at 0x7fb612296a20>,
#  'issued': <gensim.models.keyedvectors.Vocab at 0x7fb6127eecf8>,
#  'cropping': <gensim.models.keyedvectors.Vocab at 0x7fb61246dc50>,
#  'barn': <gensim.models.keyedvectors.Vocab at 0x7fb612952fd0>,
#  'foe': <gensim.models.keyedvectors.Vocab at 0x7fb6128dfb38>,
#  'thesis': <gensim.models.keyedvectors.Vocab at 0x7fb6128ad0b8>,
#  'moviesthere': <gensim.models.keyedvectors.Vocab at 0x7fb611dd4fd0>,
#  'simpering': <gensim.models.keyedvectors.Vocab at 0x7fb6125faf60>,
#  'carlos': <gensim.models.keyedvectors.Vocab at 0x7fb6129bfe48>,
#  'unable': <gensim.models.keyedvectors.Vocab at 0x7fb612afd630>,
#  'profanities': <gensim.models.keyedvectors.Vocab at 0x7fb61234c978>,
#  'burden': <gensim.models.keyedvectors.Vocab at 0x7fb61293a9e8>,
#  'hague': <gensim.models.keyedvectors.Vocab at 0x7fb611ad5160>,
#  'diedthe': <gensim.models.keyedvectors.Vocab at 0x7fb6122326a0>,
#  'rainfall': <gensim.models.keyedvectors.Vocab at 0x7fb611e17400>,
#  'humoristic': <gensim.models.keyedvectors.Vocab at 0x7fb611be3dd8>,
#  'coalesce': <gensim.models.keyedvectors.Vocab at 0x7fb612269630>,
#  'trailer!': <gensim.models.keyedvectors.Vocab at 0x7fb611e19630>,
#  'alligators': <gensim.models.keyedvectors.Vocab at 0x7fb6125fabe0>,
#  'fidgeting': <gensim.models.keyedvectors.Vocab at 0x7fb61236def0>,
#  'accuse': <gensim.models.keyedvectors.Vocab at 0x7fb61280cb38>,
#  'good-bad': <gensim.models.keyedvectors.Vocab at 0x7fb611b83978>,
#  'prelude': <gensim.models.keyedvectors.Vocab at 0x7fb612775208>,
#  'monarch': <gensim.models.keyedvectors.Vocab at 0x7fb6127cf1d0>,
#  'shekhar': <gensim.models.keyedvectors.Vocab at 0x7fb612431390>,
#  '1995s': <gensim.models.keyedvectors.Vocab at 0x7fb611b7f780>,
#  'afoot': <gensim.models.keyedvectors.Vocab at 0x7fb612650710>,
#  'kimiko': <gensim.models.keyedvectors.Vocab at 0x7fb611bdaeb8>,
#  'cashiers': <gensim.models.keyedvectors.Vocab at 0x7fb611c7bef0>,
#  'volante': <gensim.models.keyedvectors.Vocab at 0x7fb611ac4a58>,
#  'waybut': <gensim.models.keyedvectors.Vocab at 0x7fb6121f2400>,
#  'arc': <gensim.models.keyedvectors.Vocab at 0x7fb612a50fd0>,
#  'park:': <gensim.models.keyedvectors.Vocab at 0x7fb61223e7f0>,
#  '-great': <gensim.models.keyedvectors.Vocab at 0x7fb611d2d5c0>,
#  'vial': <gensim.models.keyedvectors.Vocab at 0x7fb6123f4d30>,
#  'reincarnate': <gensim.models.keyedvectors.Vocab at 0x7fb6121a5400>,
#  'sported': <gensim.models.keyedvectors.Vocab at 0x7fb612512b38>,
#  'trollop': <gensim.models.keyedvectors.Vocab at 0x7fb611b7fa58>,
#  'flies': <gensim.models.keyedvectors.Vocab at 0x7fb612a86198>,
#  'organizing': <gensim.models.keyedvectors.Vocab at 0x7fb61254add8>,
#  '2003': <gensim.models.keyedvectors.Vocab at 0x7fb612a892e8>,
#  'directorsproducers': <gensim.models.keyedvectors.Vocab at 0x7fb612163160>,
#  'brutality': <gensim.models.keyedvectors.Vocab at 0x7fb612a38ef0>,
#  'polish': <gensim.models.keyedvectors.Vocab at 0x7fb612a715c0>,
#  'ahoy': <gensim.models.keyedvectors.Vocab at 0x7fb611cfcd68>,
#  'purchase': <gensim.models.keyedvectors.Vocab at 0x7fb612a81cf8>,
#  'smokers': <gensim.models.keyedvectors.Vocab at 0x7fb612557e48>,
#  'hehe': <gensim.models.keyedvectors.Vocab at 0x7fb6124955f8>,
#  'culpable': <gensim.models.keyedvectors.Vocab at 0x7fb611db9c50>,
#  'drusilla': <gensim.models.keyedvectors.Vocab at 0x7fb611cf9e10>,
#  'preclude': <gensim.models.keyedvectors.Vocab at 0x7fb612416e48>,
#  'zerg': <gensim.models.keyedvectors.Vocab at 0x7fb611d1b4a8>,
#  'prolific': <gensim.models.keyedvectors.Vocab at 0x7fb61297f940>,
#  'spitting': <gensim.models.keyedvectors.Vocab at 0x7fb612924f28>,
#  'geldof': <gensim.models.keyedvectors.Vocab at 0x7fb6122dcba8>,
#  'off-screen': <gensim.models.keyedvectors.Vocab at 0x7fb6129e6390>,
#  'hooda': <gensim.models.keyedvectors.Vocab at 0x7fb612484e80>,
#  'fargo': <gensim.models.keyedvectors.Vocab at 0x7fb61283f908>,
#  'itone': <gensim.models.keyedvectors.Vocab at 0x7fb6123f1ac8>,
#  'controllers': <gensim.models.keyedvectors.Vocab at 0x7fb611c1eb00>,
#  'nelligan': <gensim.models.keyedvectors.Vocab at 0x7fb61220d160>,
#  'phone-in': <gensim.models.keyedvectors.Vocab at 0x7fb611b5d3c8>,
#  'shemp': <gensim.models.keyedvectors.Vocab at 0x7fb61282f3c8>,
#  'colm': <gensim.models.keyedvectors.Vocab at 0x7fb6125afb38>,
#  'unbeatable': <gensim.models.keyedvectors.Vocab at 0x7fb6126c7358>,
#  'leak': <gensim.models.keyedvectors.Vocab at 0x7fb612896a90>,
#  '$950': <gensim.models.keyedvectors.Vocab at 0x7fb611df2e10>,
#  'bolshevik': <gensim.models.keyedvectors.Vocab at 0x7fb611b99cc0>,
#  'loli': <gensim.models.keyedvectors.Vocab at 0x7fb611d18e10>,
#  'stop!': <gensim.models.keyedvectors.Vocab at 0x7fb6125c7be0>,
#  'johanson': <gensim.models.keyedvectors.Vocab at 0x7fb612237c88>,
#  'exorcism': <gensim.models.keyedvectors.Vocab at 0x7fb612887a20>,
#  'phantom': <gensim.models.keyedvectors.Vocab at 0x7fb612a73e10>,
#  'eigeman': <gensim.models.keyedvectors.Vocab at 0x7fb611df2b70>,
#  'jamal': <gensim.models.keyedvectors.Vocab at 0x7fb611ac98d0>,
#  'merits': <gensim.models.keyedvectors.Vocab at 0x7fb612a30438>,
#  'scenery-chewing': <gensim.models.keyedvectors.Vocab at 0x7fb612505cc0>,
#  'conceives': <gensim.models.keyedvectors.Vocab at 0x7fb61233e128>,
#  'lanas': <gensim.models.keyedvectors.Vocab at 0x7fb61243c630>,
#  'samoan': <gensim.models.keyedvectors.Vocab at 0x7fb61248a748>,
#  'sasquatch': <gensim.models.keyedvectors.Vocab at 0x7fb6128e7e48>,
#  'bladed': <gensim.models.keyedvectors.Vocab at 0x7fb611cd8ba8>,
#  'bathsheba': <gensim.models.keyedvectors.Vocab at 0x7fb6126976a0>,
#  'saudi': <gensim.models.keyedvectors.Vocab at 0x7fb6125608d0>,
#  'maintenance': <gensim.models.keyedvectors.Vocab at 0x7fb6127a8438>,
#  'lycanthrope': <gensim.models.keyedvectors.Vocab at 0x7fb611dd4a58>,
#  'soap-opera': <gensim.models.keyedvectors.Vocab at 0x7fb6127cce80>,
#  'heads;': <gensim.models.keyedvectors.Vocab at 0x7fb611ada2e8>,
#  'charro': <gensim.models.keyedvectors.Vocab at 0x7fb6125f4c18>,
#  'spotlight': <gensim.models.keyedvectors.Vocab at 0x7fb6129e62e8>,
#  'guerrero': <gensim.models.keyedvectors.Vocab at 0x7fb61269d748>,
#  'drained': <gensim.models.keyedvectors.Vocab at 0x7fb6128c6d30>,
#  'versioni': <gensim.models.keyedvectors.Vocab at 0x7fb61237e978>,
#  'visions': <gensim.models.keyedvectors.Vocab at 0x7fb612aa36d8>,
#  'midi': <gensim.models.keyedvectors.Vocab at 0x7fb6122c0908>,
#  'suhasini': <gensim.models.keyedvectors.Vocab at 0x7fb611db3898>,
#  'became': <gensim.models.keyedvectors.Vocab at 0x7fb612b38cc0>,
#  'usage': <gensim.models.keyedvectors.Vocab at 0x7fb6128f22e8>,
#  'izabella': <gensim.models.keyedvectors.Vocab at 0x7fb6122f0f98>,
#  'eden': <gensim.models.keyedvectors.Vocab at 0x7fb6128347f0>,
#  'gabriellas': <gensim.models.keyedvectors.Vocab at 0x7fb611c3eb70>,
#  'ice-ts': <gensim.models.keyedvectors.Vocab at 0x7fb611adac88>,
#  'insomniacs': <gensim.models.keyedvectors.Vocab at 0x7fb61267a278>,
#  'phantasms': <gensim.models.keyedvectors.Vocab at 0x7fb6122fbcc0>,
#  'singers': <gensim.models.keyedvectors.Vocab at 0x7fb612a60898>,
#  'rexs': <gensim.models.keyedvectors.Vocab at 0x7fb61235d160>,
#  'life:': <gensim.models.keyedvectors.Vocab at 0x7fb612831ef0>,
#  'vague': <gensim.models.keyedvectors.Vocab at 0x7fb612a6e208>,
#  'walls;': <gensim.models.keyedvectors.Vocab at 0x7fb611aeccf8>,
#  'superpowers': <gensim.models.keyedvectors.Vocab at 0x7fb6127a6048>,
#  'kanae': <gensim.models.keyedvectors.Vocab at 0x7fb611e28400>,
#  'reeves': <gensim.models.keyedvectors.Vocab at 0x7fb612aa5be0>,
#  'be:': <gensim.models.keyedvectors.Vocab at 0x7fb6128f5e48>,
#  'hooked': <gensim.models.keyedvectors.Vocab at 0x7fb612ad2898>,
#  'valleys': <gensim.models.keyedvectors.Vocab at 0x7fb612413d30>,
#  'robustly': <gensim.models.keyedvectors.Vocab at 0x7fb611b9db38>,
#  'hipper': <gensim.models.keyedvectors.Vocab at 0x7fb611de84e0>,
#  'coherently': <gensim.models.keyedvectors.Vocab at 0x7fb6124c6d30>,
#  'herald': <gensim.models.keyedvectors.Vocab at 0x7fb612544eb8>,
#  'burglars': <gensim.models.keyedvectors.Vocab at 0x7fb61262d198>,
#  'communicated': <gensim.models.keyedvectors.Vocab at 0x7fb612750630>,
#  'devoid': <gensim.models.keyedvectors.Vocab at 0x7fb612a6ee80>,
#  'femme-fatale': <gensim.models.keyedvectors.Vocab at 0x7fb611c6a8d0>,
#  'photographs': <gensim.models.keyedvectors.Vocab at 0x7fb6129b12b0>,
#  'stowaway': <gensim.models.keyedvectors.Vocab at 0x7fb6122f6358>,
#  'grapple': <gensim.models.keyedvectors.Vocab at 0x7fb612572b00>,
#  'thongs': <gensim.models.keyedvectors.Vocab at 0x7fb6121fe198>,
#  'bentley': <gensim.models.keyedvectors.Vocab at 0x7fb6127a0128>,
#  'zambrano': <gensim.models.keyedvectors.Vocab at 0x7fb6123d2710>,
#  'tracker': <gensim.models.keyedvectors.Vocab at 0x7fb61251db70>,
#  'sánchez': <gensim.models.keyedvectors.Vocab at 0x7fb611d30080>,
#  'ago;': <gensim.models.keyedvectors.Vocab at 0x7fb612520438>,
#  'somalia': <gensim.models.keyedvectors.Vocab at 0x7fb6122939b0>,
#  'unwed': <gensim.models.keyedvectors.Vocab at 0x7fb6123ca278>,
#  'roberta': <gensim.models.keyedvectors.Vocab at 0x7fb6128e7b38>,
#  'knives': <gensim.models.keyedvectors.Vocab at 0x7fb6129a2dd8>,
#  'gestures': <gensim.models.keyedvectors.Vocab at 0x7fb6129acd30>,
#  'primate': <gensim.models.keyedvectors.Vocab at 0x7fb6124c8ba8>,
#  'graboids': <gensim.models.keyedvectors.Vocab at 0x7fb612515b00>,
#  'criminally': <gensim.models.keyedvectors.Vocab at 0x7fb612957828>,
#  'afterward': <gensim.models.keyedvectors.Vocab at 0x7fb612a07278>,
#  'garnished': <gensim.models.keyedvectors.Vocab at 0x7fb611ab04e0>,
#  'sons': <gensim.models.keyedvectors.Vocab at 0x7fb612b173c8>,
#  'fawcett': <gensim.models.keyedvectors.Vocab at 0x7fb6129924a8>,
#  'eb': <gensim.models.keyedvectors.Vocab at 0x7fb611d41240>,
#  'signaling': <gensim.models.keyedvectors.Vocab at 0x7fb61225b160>,
#  'disconnect': <gensim.models.keyedvectors.Vocab at 0x7fb6125aa518>,
#  'expressionless': <gensim.models.keyedvectors.Vocab at 0x7fb6127a0be0>,
#  'charitable': <gensim.models.keyedvectors.Vocab at 0x7fb6127d2d30>,
#  'band': <gensim.models.keyedvectors.Vocab at 0x7fb612b53278>,
#  'introverted': <gensim.models.keyedvectors.Vocab at 0x7fb612791e10>,
#  'life-time': <gensim.models.keyedvectors.Vocab at 0x7fb611b71518>,
#  'pre-release': <gensim.models.keyedvectors.Vocab at 0x7fb61254aa58>,
#  'steve': <gensim.models.keyedvectors.Vocab at 0x7fb612b530f0>,
#  'beautifully': <gensim.models.keyedvectors.Vocab at 0x7fb612b53898>,
#  'director:': <gensim.models.keyedvectors.Vocab at 0x7fb6127605c0>,
#  'anti-establishment': <gensim.models.keyedvectors.Vocab at 0x7fb6126dcba8>,
#  'undeterred': <gensim.models.keyedvectors.Vocab at 0x7fb611bfad30>,
#  'gracies': <gensim.models.keyedvectors.Vocab at 0x7fb61249d2b0>,
#  'overwhelms': <gensim.models.keyedvectors.Vocab at 0x7fb612427c18>,
#  'cooler': <gensim.models.keyedvectors.Vocab at 0x7fb6128aa630>,
#  'candies': <gensim.models.keyedvectors.Vocab at 0x7fb611ac76d8>,
#  'reverts': <gensim.models.keyedvectors.Vocab at 0x7fb61267cd30>,
#  'perpetuated': <gensim.models.keyedvectors.Vocab at 0x7fb6123fcf28>,
#  'luna': <gensim.models.keyedvectors.Vocab at 0x7fb6127b67f0>,
#  'storythat': <gensim.models.keyedvectors.Vocab at 0x7fb611cc1748>,
#  'balletic': <gensim.models.keyedvectors.Vocab at 0x7fb6123df0b8>,
#  'wisconsin': <gensim.models.keyedvectors.Vocab at 0x7fb612845048>,
#  'populations': <gensim.models.keyedvectors.Vocab at 0x7fb6125e7828>,
#  'effortlessly': <gensim.models.keyedvectors.Vocab at 0x7fb6129ba748>,
#  'buck-toothed': <gensim.models.keyedvectors.Vocab at 0x7fb611ca3a90>,
#  'exploitational': <gensim.models.keyedvectors.Vocab at 0x7fb611db3908>,
#  'kinison': <gensim.models.keyedvectors.Vocab at 0x7fb611db0a90>,
#  'instructed': <gensim.models.keyedvectors.Vocab at 0x7fb6127d2160>,
#  'achieving': <gensim.models.keyedvectors.Vocab at 0x7fb612965358>,
#  'first-run': <gensim.models.keyedvectors.Vocab at 0x7fb611c9df60>,
#  'all-star': <gensim.models.keyedvectors.Vocab at 0x7fb61299ae48>,
#  'back;': <gensim.models.keyedvectors.Vocab at 0x7fb612568860>,
#  'agro': <gensim.models.keyedvectors.Vocab at 0x7fb61219c9e8>,
#  'care-a-lot': <gensim.models.keyedvectors.Vocab at 0x7fb611cd0198>,
#  'two-reel': <gensim.models.keyedvectors.Vocab at 0x7fb611cbb358>,
#  'bulletin': <gensim.models.keyedvectors.Vocab at 0x7fb61257cfd0>,
#  'heresy': <gensim.models.keyedvectors.Vocab at 0x7fb612581080>,
#  'secondsthe': <gensim.models.keyedvectors.Vocab at 0x7fb611b2b4e0>,
#  'disproven': <gensim.models.keyedvectors.Vocab at 0x7fb611bc2710>,
#  'abby': <gensim.models.keyedvectors.Vocab at 0x7fb612842a20>,
#  'dongmakgol': <gensim.models.keyedvectors.Vocab at 0x7fb612528550>,
#  'dubs': <gensim.models.keyedvectors.Vocab at 0x7fb612593dd8>,
#  'mai': <gensim.models.keyedvectors.Vocab at 0x7fb6128a4fd0>,
#  'vetted': <gensim.models.keyedvectors.Vocab at 0x7fb611c15668>,
#  'wipes': <gensim.models.keyedvectors.Vocab at 0x7fb6128205c0>,
#  'buttram': <gensim.models.keyedvectors.Vocab at 0x7fb611b21080>,
#  'rajko': <gensim.models.keyedvectors.Vocab at 0x7fb612163748>,
#  'ebenezer': <gensim.models.keyedvectors.Vocab at 0x7fb6125aaba8>,
#  'gyllenhall': <gensim.models.keyedvectors.Vocab at 0x7fb611bb3588>,
#  'puck': <gensim.models.keyedvectors.Vocab at 0x7fb612789e10>,
#  'fornication': <gensim.models.keyedvectors.Vocab at 0x7fb611c63320>,
#  'lafleur': <gensim.models.keyedvectors.Vocab at 0x7fb611d93320>,
#  'jacksons': <gensim.models.keyedvectors.Vocab at 0x7fb612a19780>,
#  'lookalikes': <gensim.models.keyedvectors.Vocab at 0x7fb61217f860>,
#  'documenting': <gensim.models.keyedvectors.Vocab at 0x7fb6127cfe80>,
#  'cthulhu': <gensim.models.keyedvectors.Vocab at 0x7fb611c63668>,
#  '1961': <gensim.models.keyedvectors.Vocab at 0x7fb61293ac18>,
#  'determines': <gensim.models.keyedvectors.Vocab at 0x7fb6126a56a0>,
#  'carlotta': <gensim.models.keyedvectors.Vocab at 0x7fb61234eb00>,
#  'sentiments': <gensim.models.keyedvectors.Vocab at 0x7fb612954160>,
#  'erendira': <gensim.models.keyedvectors.Vocab at 0x7fb6123c5f60>,
#  'co-workers': <gensim.models.keyedvectors.Vocab at 0x7fb6129060f0>,
#  'slowest': <gensim.models.keyedvectors.Vocab at 0x7fb6125285c0>,
#  'channel!': <gensim.models.keyedvectors.Vocab at 0x7fb6121d17b8>,
#  'leslie': <gensim.models.keyedvectors.Vocab at 0x7fb612aae780>,
#  'reclining': <gensim.models.keyedvectors.Vocab at 0x7fb611b375c0>,
#  'self-serious': <gensim.models.keyedvectors.Vocab at 0x7fb611d4d710>,
#  'gun-slinging': <gensim.models.keyedvectors.Vocab at 0x7fb611aec470>,
#  'expire': <gensim.models.keyedvectors.Vocab at 0x7fb6121e8e80>,
#  'tournament': <gensim.models.keyedvectors.Vocab at 0x7fb612937b70>,
#  'dreary': <gensim.models.keyedvectors.Vocab at 0x7fb612a2be80>,
#  'who`s': <gensim.models.keyedvectors.Vocab at 0x7fb612215588>,
#  'rationalization': <gensim.models.keyedvectors.Vocab at 0x7fb6122011d0>,
#  'male-female': <gensim.models.keyedvectors.Vocab at 0x7fb611ddf668>,
#  'drunkenly': <gensim.models.keyedvectors.Vocab at 0x7fb612290fd0>,
#  'c+': <gensim.models.keyedvectors.Vocab at 0x7fb6125361d0>,
#  'instruct': <gensim.models.keyedvectors.Vocab at 0x7fb6124ba390>,
#  'fmvs': <gensim.models.keyedvectors.Vocab at 0x7fb611cafb38>,
#  'shocking;': <gensim.models.keyedvectors.Vocab at 0x7fb611ce7128>,
#  'velde': <gensim.models.keyedvectors.Vocab at 0x7fb611c1b6a0>,
#  'long-distance': <gensim.models.keyedvectors.Vocab at 0x7fb612138198>,
#  'outta': <gensim.models.keyedvectors.Vocab at 0x7fb612950b00>,
#  'udo': <gensim.models.keyedvectors.Vocab at 0x7fb612619d30>,
#  'away!': <gensim.models.keyedvectors.Vocab at 0x7fb6128f2358>,
#  'avoid': <gensim.models.keyedvectors.Vocab at 0x7fb612b382b0>,
#  'inclusion': <gensim.models.keyedvectors.Vocab at 0x7fb612a24470>,
#  'whitmans': <gensim.models.keyedvectors.Vocab at 0x7fb611b515c0>,
#  'choreographed': <gensim.models.keyedvectors.Vocab at 0x7fb612a98978>,
#  'flatly': <gensim.models.keyedvectors.Vocab at 0x7fb61268f9e8>,
#  'timesbut': <gensim.models.keyedvectors.Vocab at 0x7fb612552940>,
#  'grownups': <gensim.models.keyedvectors.Vocab at 0x7fb6124ff400>,
#  'fulfilled': <gensim.models.keyedvectors.Vocab at 0x7fb6128c9940>,
#  'boiling': <gensim.models.keyedvectors.Vocab at 0x7fb612820668>,
#  'snacks': <gensim.models.keyedvectors.Vocab at 0x7fb6125a8588>,
#  'beef': <gensim.models.keyedvectors.Vocab at 0x7fb612903f28>,
#  'aspire': <gensim.models.keyedvectors.Vocab at 0x7fb61280f358>,
#  'husseins': <gensim.models.keyedvectors.Vocab at 0x7fb611bbf048>,
#  'robber': <gensim.models.keyedvectors.Vocab at 0x7fb61295d7b8>,
#  'fx': <gensim.models.keyedvectors.Vocab at 0x7fb612ac83c8>,
#  'goal': <gensim.models.keyedvectors.Vocab at 0x7fb612ab7da0>,
#  'mate!': <gensim.models.keyedvectors.Vocab at 0x7fb611df05c0>,
#  'repents': <gensim.models.keyedvectors.Vocab at 0x7fb6121a5c18>,
#  'banshees': <gensim.models.keyedvectors.Vocab at 0x7fb611d0dac8>,
#  'diehard': <gensim.models.keyedvectors.Vocab at 0x7fb6124ffe80>,
#  'ryoko': <gensim.models.keyedvectors.Vocab at 0x7fb61244d9b0>,
#  'rekindles': <gensim.models.keyedvectors.Vocab at 0x7fb612135048>,
#  'glorification': <gensim.models.keyedvectors.Vocab at 0x7fb6126b7d30>,
#  'fix-it': <gensim.models.keyedvectors.Vocab at 0x7fb611afdc18>,
#  'distortion': <gensim.models.keyedvectors.Vocab at 0x7fb6127d7128>,
#  'underdog': <gensim.models.keyedvectors.Vocab at 0x7fb6128b38d0>,
#  'champions': <gensim.models.keyedvectors.Vocab at 0x7fb6128917f0>,
#  'nature;': <gensim.models.keyedvectors.Vocab at 0x7fb611b74a20>,
#  'rico': <gensim.models.keyedvectors.Vocab at 0x7fb61290c8d0>,
#  'thou': <gensim.models.keyedvectors.Vocab at 0x7fb61289ecc0>,
#  'blair': <gensim.models.keyedvectors.Vocab at 0x7fb612ab02e8>,
#  'freezing': <gensim.models.keyedvectors.Vocab at 0x7fb61286cbe0>,
#  'wide': <gensim.models.keyedvectors.Vocab at 0x7fb612b0cb70>,
#  'stirred': <gensim.models.keyedvectors.Vocab at 0x7fb6127e7358>,
#  'ewa': <gensim.models.keyedvectors.Vocab at 0x7fb61232c0b8>,
#  'con': <gensim.models.keyedvectors.Vocab at 0x7fb612ae1be0>,
#  'bungles': <gensim.models.keyedvectors.Vocab at 0x7fb611c07240>,
#  'lucked': <gensim.models.keyedvectors.Vocab at 0x7fb611deda90>,
#  'kazakh': <gensim.models.keyedvectors.Vocab at 0x7fb611c6ca20>,
#  'joshua': <gensim.models.keyedvectors.Vocab at 0x7fb6129cc550>,
#  'americana': <gensim.models.keyedvectors.Vocab at 0x7fb6127c1908>,
#  'passer': <gensim.models.keyedvectors.Vocab at 0x7fb611d09c18>,
#  'totoro': <gensim.models.keyedvectors.Vocab at 0x7fb611b743c8>,
#  'pherides': <gensim.models.keyedvectors.Vocab at 0x7fb6124b00f0>,
#  'sisterthe': <gensim.models.keyedvectors.Vocab at 0x7fb611beff28>,
#  'versionthe': <gensim.models.keyedvectors.Vocab at 0x7fb61255d358>,
#  'lacombe': <gensim.models.keyedvectors.Vocab at 0x7fb61238d518>,
#  'boy-meets-girl': <gensim.models.keyedvectors.Vocab at 0x7fb611de8470>,
#  'voicing': <gensim.models.keyedvectors.Vocab at 0x7fb61275e978>,
#  'jokes': <gensim.models.keyedvectors.Vocab at 0x7fb612b2cba8>,
#  'instigator': <gensim.models.keyedvectors.Vocab at 0x7fb61223add8>,
#  'popping': <gensim.models.keyedvectors.Vocab at 0x7fb612a0a6a0>,
#  'dopes': <gensim.models.keyedvectors.Vocab at 0x7fb612215e10>,
#  'sg1': <gensim.models.keyedvectors.Vocab at 0x7fb612473c18>,
#  'anyonethe': <gensim.models.keyedvectors.Vocab at 0x7fb6123bc6d8>,
#  'offscreen': <gensim.models.keyedvectors.Vocab at 0x7fb6126b4588>,
#  'spew': <gensim.models.keyedvectors.Vocab at 0x7fb612736ef0>,
#  'weakling': <gensim.models.keyedvectors.Vocab at 0x7fb61256fb70>,
#  'fiancée': <gensim.models.keyedvectors.Vocab at 0x7fb612a21a90>,
#  'bacon': <gensim.models.keyedvectors.Vocab at 0x7fb612a17940>,
#  'reception': <gensim.models.keyedvectors.Vocab at 0x7fb612934908>,
#  '*why*': <gensim.models.keyedvectors.Vocab at 0x7fb611b4bda0>,
#  'unavailability': <gensim.models.keyedvectors.Vocab at 0x7fb611b942b0>,
#  'showin': <gensim.models.keyedvectors.Vocab at 0x7fb611b46940>,
#  'routing': <gensim.models.keyedvectors.Vocab at 0x7fb6121dc198>,
#  'heroics': <gensim.models.keyedvectors.Vocab at 0x7fb6127e7898>,
#  'overdosing': <gensim.models.keyedvectors.Vocab at 0x7fb612163d68>,
#  'itwhat': <gensim.models.keyedvectors.Vocab at 0x7fb6126eeb00>,
#  'shifting': <gensim.models.keyedvectors.Vocab at 0x7fb612917978>,
#  'carrier': <gensim.models.keyedvectors.Vocab at 0x7fb6128edac8>,
#  'sobieski': <gensim.models.keyedvectors.Vocab at 0x7fb6127d2cf8>,
#  'buzzer': <gensim.models.keyedvectors.Vocab at 0x7fb611dcb5f8>,
#  'messily': <gensim.models.keyedvectors.Vocab at 0x7fb61219cd68>,
#  'hamm': <gensim.models.keyedvectors.Vocab at 0x7fb6122ff860>,
#  'lima': <gensim.models.keyedvectors.Vocab at 0x7fb6122d65c0>,
#  'revise': <gensim.models.keyedvectors.Vocab at 0x7fb612497128>,
#  'meanest': <gensim.models.keyedvectors.Vocab at 0x7fb6125e2a20>,
#  'perfectly': <gensim.models.keyedvectors.Vocab at 0x7fb612b3d710>,
#  'lindsays': <gensim.models.keyedvectors.Vocab at 0x7fb611e177f0>,
#  'straightening': <gensim.models.keyedvectors.Vocab at 0x7fb611aad748>,
#  'mumm': <gensim.models.keyedvectors.Vocab at 0x7fb611b37a20>,
#  'hangers-on': <gensim.models.keyedvectors.Vocab at 0x7fb612144358>,
#  'instalments': <gensim.models.keyedvectors.Vocab at 0x7fb611cf6d30>,
#  'sampled': <gensim.models.keyedvectors.Vocab at 0x7fb611dea358>,
#  'starship': <gensim.models.keyedvectors.Vocab at 0x7fb61297f5c0>,
#  'dolf': <gensim.models.keyedvectors.Vocab at 0x7fb611d476a0>,
#  'hangar': <gensim.models.keyedvectors.Vocab at 0x7fb61249df60>,
#  'warfare': <gensim.models.keyedvectors.Vocab at 0x7fb6129a64e0>,
#  'affecting': <gensim.models.keyedvectors.Vocab at 0x7fb612a12d68>,
#  'sugary': <gensim.models.keyedvectors.Vocab at 0x7fb6127b1e10>,
#  'dwindles': <gensim.models.keyedvectors.Vocab at 0x7fb611be6828>,
#  'informing': <gensim.models.keyedvectors.Vocab at 0x7fb612778f60>,
#  'thingy': <gensim.models.keyedvectors.Vocab at 0x7fb612602198>,
#  'scaly': <gensim.models.keyedvectors.Vocab at 0x7fb612363c18>,
#  'cemented': <gensim.models.keyedvectors.Vocab at 0x7fb6126eec88>,
#  'planting': <gensim.models.keyedvectors.Vocab at 0x7fb612739668>,
#  'domineering': <gensim.models.keyedvectors.Vocab at 0x7fb6127d7fd0>,
#  'ethics': <gensim.models.keyedvectors.Vocab at 0x7fb61295f748>,
#  'techniquethe': <gensim.models.keyedvectors.Vocab at 0x7fb611c72ba8>,
#  'orville': <gensim.models.keyedvectors.Vocab at 0x7fb61276ac88>,
#  'rom-com': <gensim.models.keyedvectors.Vocab at 0x7fb6125af7f0>,
#  'malls': <gensim.models.keyedvectors.Vocab at 0x7fb6125e2d30>,
#  'starbase': <gensim.models.keyedvectors.Vocab at 0x7fb611c18208>,
#  'hosting': <gensim.models.keyedvectors.Vocab at 0x7fb6125be0f0>,
#  'phonies': <gensim.models.keyedvectors.Vocab at 0x7fb611e0a780>,
#  'home-movie': <gensim.models.keyedvectors.Vocab at 0x7fb611d41f60>,
#  'persian': <gensim.models.keyedvectors.Vocab at 0x7fb612760710>,
#  'blacklist': <gensim.models.keyedvectors.Vocab at 0x7fb612285d68>,
#  'charactersit': <gensim.models.keyedvectors.Vocab at 0x7fb612305da0>,
#  'curiosity': <gensim.models.keyedvectors.Vocab at 0x7fb612ac8908>,
#  'fake': <gensim.models.keyedvectors.Vocab at 0x7fb612b4ca20>,
#  'anti-nazi': <gensim.models.keyedvectors.Vocab at 0x7fb61237e9b0>,
#  'connellys': <gensim.models.keyedvectors.Vocab at 0x7fb61224c0b8>,
#  'yeoreum': <gensim.models.keyedvectors.Vocab at 0x7fb611afb6d8>,
#  'unaccountably': <gensim.models.keyedvectors.Vocab at 0x7fb61220f2e8>,
#  'gulags': <gensim.models.keyedvectors.Vocab at 0x7fb611c27f28>,
#  'f-14s': <gensim.models.keyedvectors.Vocab at 0x7fb611c374a8>,
#  'skyscrapers': <gensim.models.keyedvectors.Vocab at 0x7fb6123df908>,
#  'damage': <gensim.models.keyedvectors.Vocab at 0x7fb612a7ea20>,
#  'cocteaus': <gensim.models.keyedvectors.Vocab at 0x7fb611bdd3c8>,
#  'dockside': <gensim.models.keyedvectors.Vocab at 0x7fb6122b0470>,
#  'disorientation': <gensim.models.keyedvectors.Vocab at 0x7fb612400a20>,
#  'littles': <gensim.models.keyedvectors.Vocab at 0x7fb611d1ef28>,
#  'oh!': <gensim.models.keyedvectors.Vocab at 0x7fb6128154e0>,
#  'symptoms': <gensim.models.keyedvectors.Vocab at 0x7fb61287f630>,
#  'facial': <gensim.models.keyedvectors.Vocab at 0x7fb612aaee80>,
#  'shame': <gensim.models.keyedvectors.Vocab at 0x7fb612b3da90>,
#  'disjointed': <gensim.models.keyedvectors.Vocab at 0x7fb612a76860>,
#  'necklace': <gensim.models.keyedvectors.Vocab at 0x7fb6127fc6d8>,
#  'hellfire': <gensim.models.keyedvectors.Vocab at 0x7fb612520f60>,
#  'p:': <gensim.models.keyedvectors.Vocab at 0x7fb611e28ac8>,
#  'biting': <gensim.models.keyedvectors.Vocab at 0x7fb612a24ac8>,
#  'julietta': <gensim.models.keyedvectors.Vocab at 0x7fb611df01d0>,
#  'rightness': <gensim.models.keyedvectors.Vocab at 0x7fb611caf898>,
#  'darling': <gensim.models.keyedvectors.Vocab at 0x7fb6129e6e80>,
#  'duplicated': <gensim.models.keyedvectors.Vocab at 0x7fb6126ffda0>,
#  'overheard': <gensim.models.keyedvectors.Vocab at 0x7fb6125e2518>,
#  'agenda': <gensim.models.keyedvectors.Vocab at 0x7fb612a2e9b0>,
#  're-animate': <gensim.models.keyedvectors.Vocab at 0x7fb6121a7e10>,
#  'buseys': <gensim.models.keyedvectors.Vocab at 0x7fb6123f9358>,
#  'texan': <gensim.models.keyedvectors.Vocab at 0x7fb61276d4a8>,
#  'jorgen': <gensim.models.keyedvectors.Vocab at 0x7fb611c1e278>,
#  'menace': <gensim.models.keyedvectors.Vocab at 0x7fb612a73400>,
#  'nadia': <gensim.models.keyedvectors.Vocab at 0x7fb6127ae588>,
#  'pliers': <gensim.models.keyedvectors.Vocab at 0x7fb61228a518>,
#  'aarti': <gensim.models.keyedvectors.Vocab at 0x7fb6121a2cf8>,
#  'womens': <gensim.models.keyedvectors.Vocab at 0x7fb612a81e80>,
#  'veidt': <gensim.models.keyedvectors.Vocab at 0x7fb6127a8390>,
#  'rathbones': <gensim.models.keyedvectors.Vocab at 0x7fb612220c50>,
#  'forever;': <gensim.models.keyedvectors.Vocab at 0x7fb611d15b00>,
#  'goverment': <gensim.models.keyedvectors.Vocab at 0x7fb611badd30>,
#  'glamour': <gensim.models.keyedvectors.Vocab at 0x7fb6128ed208>,
#  'florey': <gensim.models.keyedvectors.Vocab at 0x7fb612329080>,
#  'since': <gensim.models.keyedvectors.Vocab at 0x7fb6158661d0>,
#  'queuing': <gensim.models.keyedvectors.Vocab at 0x7fb611e205f8>,
#  'too-long': <gensim.models.keyedvectors.Vocab at 0x7fb611b899b0>,
#  'shortcuts': <gensim.models.keyedvectors.Vocab at 0x7fb6121bc128>,
#  'nerve-jangling': <gensim.models.keyedvectors.Vocab at 0x7fb611bc2e10>,
#  'editors': <gensim.models.keyedvectors.Vocab at 0x7fb61295a550>,
#  'fernandez': <gensim.models.keyedvectors.Vocab at 0x7fb6126bd4e0>,
#  'egomania': <gensim.models.keyedvectors.Vocab at 0x7fb611e19780>,
#  'artsy-fartsy': <gensim.models.keyedvectors.Vocab at 0x7fb612378160>,
#  'devoured': <gensim.models.keyedvectors.Vocab at 0x7fb61278c898>,
#  'eroticism': <gensim.models.keyedvectors.Vocab at 0x7fb612903160>,
#  'pre-civil': <gensim.models.keyedvectors.Vocab at 0x7fb611d9e438>,
#  'spurious': <gensim.models.keyedvectors.Vocab at 0x7fb6124168d0>,
#  'hurts': <gensim.models.keyedvectors.Vocab at 0x7fb612a8ee80>,
#  'unsteady': <gensim.models.keyedvectors.Vocab at 0x7fb61229b5f8>,
#  'bloodbaths': <gensim.models.keyedvectors.Vocab at 0x7fb611d7f4a8>,
#  'got': <gensim.models.keyedvectors.Vocab at 0x7fb615861e10>,
#  'riskin': <gensim.models.keyedvectors.Vocab at 0x7fb611d73748>,
#  'lerner': <gensim.models.keyedvectors.Vocab at 0x7fb61278c438>,
#  'zombified': <gensim.models.keyedvectors.Vocab at 0x7fb6125e7160>,
#  'tireless': <gensim.models.keyedvectors.Vocab at 0x7fb6123074e0>,
#  'interpretations': <gensim.models.keyedvectors.Vocab at 0x7fb612971c50>,
#  'rudolph': <gensim.models.keyedvectors.Vocab at 0x7fb6129112e8>,
#  'sweeter': <gensim.models.keyedvectors.Vocab at 0x7fb612515f60>,
#  'endeavors': <gensim.models.keyedvectors.Vocab at 0x7fb612780668>,
#  'son;': <gensim.models.keyedvectors.Vocab at 0x7fb61232e3c8>,
#  '17-year-old': <gensim.models.keyedvectors.Vocab at 0x7fb6123a9940>,
#  'anti-hero': <gensim.models.keyedvectors.Vocab at 0x7fb6129a6080>,
#  'truffaut': <gensim.models.keyedvectors.Vocab at 0x7fb612807c88>,
#  'surfboards': <gensim.models.keyedvectors.Vocab at 0x7fb611c78ac8>,
#  'shutting': <gensim.models.keyedvectors.Vocab at 0x7fb6126f1ac8>,
#  'permanently': <gensim.models.keyedvectors.Vocab at 0x7fb61292eb70>,
#  'limit': <gensim.models.keyedvectors.Vocab at 0x7fb6129eb7b8>,
#  'potboilers': <gensim.models.keyedvectors.Vocab at 0x7fb612285630>,
#  'expectation': <gensim.models.keyedvectors.Vocab at 0x7fb612a0f7f0>,
#  'putain': <gensim.models.keyedvectors.Vocab at 0x7fb612469400>,
#  'collette': <gensim.models.keyedvectors.Vocab at 0x7fb6128ea630>,
#  'steel': <gensim.models.keyedvectors.Vocab at 0x7fb612a98ac8>,
#  'event': <gensim.models.keyedvectors.Vocab at 0x7fb612b67780>,
#  'columbus': <gensim.models.keyedvectors.Vocab at 0x7fb61291a588>,
#  'civil': <gensim.models.keyedvectors.Vocab at 0x7fb612aba048>,
#  'glorified': <gensim.models.keyedvectors.Vocab at 0x7fb6128f5ac8>,
#  'inane': <gensim.models.keyedvectors.Vocab at 0x7fb612a7e518>,
#  'audio-visual': <gensim.models.keyedvectors.Vocab at 0x7fb611c4ec88>,
#  'love!': <gensim.models.keyedvectors.Vocab at 0x7fb61285a2b0>,
#  'architects': <gensim.models.keyedvectors.Vocab at 0x7fb61229fa58>,
#  'gilligans': <gensim.models.keyedvectors.Vocab at 0x7fb612807c18>,
#  'dollars!': <gensim.models.keyedvectors.Vocab at 0x7fb611d2d668>,
#  'ussr': <gensim.models.keyedvectors.Vocab at 0x7fb61283c390>,
#  'oates': <gensim.models.keyedvectors.Vocab at 0x7fb6128e12b0>,
#  'rd': <gensim.models.keyedvectors.Vocab at 0x7fb61259a6d8>,
#  'stinking': <gensim.models.keyedvectors.Vocab at 0x7fb61283cc50>,
#  'singed': <gensim.models.keyedvectors.Vocab at 0x7fb611bbc630>,
#  'runtime': <gensim.models.keyedvectors.Vocab at 0x7fb6128f8cf8>,
#  'plotall': <gensim.models.keyedvectors.Vocab at 0x7fb611d8e5c0>,
#  'chowing': <gensim.models.keyedvectors.Vocab at 0x7fb611c21668>,
#  'viewthe': <gensim.models.keyedvectors.Vocab at 0x7fb61216a6d8>,
#  'scripts': <gensim.models.keyedvectors.Vocab at 0x7fb612ab32e8>,
#  'stupefied': <gensim.models.keyedvectors.Vocab at 0x7fb611ce9240>,
#  'croon': <gensim.models.keyedvectors.Vocab at 0x7fb611cf6358>,
#  'cues': <gensim.models.keyedvectors.Vocab at 0x7fb6128edf98>,
#  'gilchrist': <gensim.models.keyedvectors.Vocab at 0x7fb612184a58>,
#  'sensitive': <gensim.models.keyedvectors.Vocab at 0x7fb612b19518>,
#  'amick': <gensim.models.keyedvectors.Vocab at 0x7fb61262ae10>,
#  'cadillac': <gensim.models.keyedvectors.Vocab at 0x7fb6126d6710>,
#  'hairball': <gensim.models.keyedvectors.Vocab at 0x7fb611c7eb38>,
#  'hosts': <gensim.models.keyedvectors.Vocab at 0x7fb612945128>,
#  'moviesthis': <gensim.models.keyedvectors.Vocab at 0x7fb61279a5f8>,
#  'mcgowans': <gensim.models.keyedvectors.Vocab at 0x7fb611dc5f98>,
#  'revealing': <gensim.models.keyedvectors.Vocab at 0x7fb612ad77f0>,
#  'nut-case': <gensim.models.keyedvectors.Vocab at 0x7fb611d9cc88>,
#  'merle': <gensim.models.keyedvectors.Vocab at 0x7fb61262a048>,
#  'idiosyncratic': <gensim.models.keyedvectors.Vocab at 0x7fb612865240>,
#  'album': <gensim.models.keyedvectors.Vocab at 0x7fb612a2e5f8>,
#  'ego-trip': <gensim.models.keyedvectors.Vocab at 0x7fb611ae9048>,
#  'hippies': <gensim.models.keyedvectors.Vocab at 0x7fb612a12b38>,
#  'plunder': <gensim.models.keyedvectors.Vocab at 0x7fb612510668>,
#  'ravage': <gensim.models.keyedvectors.Vocab at 0x7fb61224f5f8>,
#  'neutralized': <gensim.models.keyedvectors.Vocab at 0x7fb611cddfd0>,
#  'gromit': <gensim.models.keyedvectors.Vocab at 0x7fb61237ef60>,
#  'perverted': <gensim.models.keyedvectors.Vocab at 0x7fb6129b7dd8>,
#  'fido': <gensim.models.keyedvectors.Vocab at 0x7fb6128df5c0>,
#  'weep': <gensim.models.keyedvectors.Vocab at 0x7fb61287fd30>,
#  'allyson': <gensim.models.keyedvectors.Vocab at 0x7fb612632cf8>,
#  'jaimie': <gensim.models.keyedvectors.Vocab at 0x7fb611be00f0>,
#  'injury': <gensim.models.keyedvectors.Vocab at 0x7fb612a24668>,
#  'melvins': <gensim.models.keyedvectors.Vocab at 0x7fb611deab00>,
#  'whore': <gensim.models.keyedvectors.Vocab at 0x7fb6129f0048>,
#  'guyana': <gensim.models.keyedvectors.Vocab at 0x7fb611c299e8>,
#  'dorms': <gensim.models.keyedvectors.Vocab at 0x7fb612252c50>,
#  'think;': <gensim.models.keyedvectors.Vocab at 0x7fb612298a58>,
#  'birthing': <gensim.models.keyedvectors.Vocab at 0x7fb6124163c8>,
#  'jcvd': <gensim.models.keyedvectors.Vocab at 0x7fb61250def0>,
#  'meditation': <gensim.models.keyedvectors.Vocab at 0x7fb6128af278>,
#  'levi': <gensim.models.keyedvectors.Vocab at 0x7fb61276abe0>,
#  'throwers': <gensim.models.keyedvectors.Vocab at 0x7fb611c4e240>,
#  'loads': <gensim.models.keyedvectors.Vocab at 0x7fb612a819b0>,
#  'wire': <gensim.models.keyedvectors.Vocab at 0x7fb6129ff080>,
#  'weighing': <gensim.models.keyedvectors.Vocab at 0x7fb6124417b8>,
#  'unaware': <gensim.models.keyedvectors.Vocab at 0x7fb612aa3f60>,
#  'sandlers': <gensim.models.keyedvectors.Vocab at 0x7fb612954978>,
#  'kank': <gensim.models.keyedvectors.Vocab at 0x7fb611b8e358>,
#  'folly': <gensim.models.keyedvectors.Vocab at 0x7fb612869d68>,
#  'comedy;': <gensim.models.keyedvectors.Vocab at 0x7fb61276dd68>,
#  'imitates': <gensim.models.keyedvectors.Vocab at 0x7fb6126c2c88>,
#  'patent': <gensim.models.keyedvectors.Vocab at 0x7fb61250ac88>,
#  'ingenious': <gensim.models.keyedvectors.Vocab at 0x7fb612a60f60>,
#  'vampyros': <gensim.models.keyedvectors.Vocab at 0x7fb611c49128>,
#  'andress': <gensim.models.keyedvectors.Vocab at 0x7fb61253c5f8>,
#  'angela': <gensim.models.keyedvectors.Vocab at 0x7fb612a869e8>,
#  'spurred': <gensim.models.keyedvectors.Vocab at 0x7fb612568278>,
#  'lovely': <gensim.models.keyedvectors.Vocab at 0x7fb612b53208>,
#  'repairs': <gensim.models.keyedvectors.Vocab at 0x7fb6125d0898>,
#  'blackenstein': <gensim.models.keyedvectors.Vocab at 0x7fb6125f2ef0>,
#  'erosion': <gensim.models.keyedvectors.Vocab at 0x7fb611d879b0>,
#  'teen-aged': <gensim.models.keyedvectors.Vocab at 0x7fb6126ac7f0>,
#  'smoker': <gensim.models.keyedvectors.Vocab at 0x7fb6124056d8>,
#  'man!!!': <gensim.models.keyedvectors.Vocab at 0x7fb611d70a58>,
#  'rather': <gensim.models.keyedvectors.Vocab at 0x7fb615866588>,
#  'etc': <gensim.models.keyedvectors.Vocab at 0x7fb615877a90>,
#  'thatin': <gensim.models.keyedvectors.Vocab at 0x7fb612370fd0>,
#  're-hashed': <gensim.models.keyedvectors.Vocab at 0x7fb611db6208>,
#  'ps1': <gensim.models.keyedvectors.Vocab at 0x7fb612593780>,
#  '*anything*': <gensim.models.keyedvectors.Vocab at 0x7fb61221a438>,
#  'tabloids': <gensim.models.keyedvectors.Vocab at 0x7fb6125520f0>,
#  'reservation': <gensim.models.keyedvectors.Vocab at 0x7fb612852ef0>,
#  'moviein': <gensim.models.keyedvectors.Vocab at 0x7fb61283ae10>,
#  'tall:': <gensim.models.keyedvectors.Vocab at 0x7fb61228de10>,
#  'evilin': <gensim.models.keyedvectors.Vocab at 0x7fb611c871d0>,
#  'achieve': <gensim.models.keyedvectors.Vocab at 0x7fb612b269e8>,
#  'wondered': <gensim.models.keyedvectors.Vocab at 0x7fb612ad7e10>,
#  'impressive;': <gensim.models.keyedvectors.Vocab at 0x7fb6121c2390>,
#  'manoeuvre': <gensim.models.keyedvectors.Vocab at 0x7fb611b0fba8>,
#  'constitutional': <gensim.models.keyedvectors.Vocab at 0x7fb6127500f0>,
#  'steffen': <gensim.models.keyedvectors.Vocab at 0x7fb6122ad6d8>,
#  'subverting': <gensim.models.keyedvectors.Vocab at 0x7fb612405ac8>,
#  'single-minded': <gensim.models.keyedvectors.Vocab at 0x7fb61231df98>,
#  'grindhouse': <gensim.models.keyedvectors.Vocab at 0x7fb61286c978>,
#  'chair': <gensim.models.keyedvectors.Vocab at 0x7fb612acd898>,
#  'occupied': <gensim.models.keyedvectors.Vocab at 0x7fb6129b4400>,
#  'oz': <gensim.models.keyedvectors.Vocab at 0x7fb612a52208>,
#  'ziering': <gensim.models.keyedvectors.Vocab at 0x7fb612387320>,
#  'frieda': <gensim.models.keyedvectors.Vocab at 0x7fb611d41438>,
#  'pairs': <gensim.models.keyedvectors.Vocab at 0x7fb6127f9d30>,
#  'dastardly': <gensim.models.keyedvectors.Vocab at 0x7fb612874b70>,
#  'president': <gensim.models.keyedvectors.Vocab at 0x7fb612aee0f0>,
#  'begin!': <gensim.models.keyedvectors.Vocab at 0x7fb612368f98>,
#  'abandonment': <gensim.models.keyedvectors.Vocab at 0x7fb6127632b0>,
#  'feud': <gensim.models.keyedvectors.Vocab at 0x7fb61286af60>,
#  'eeriness': <gensim.models.keyedvectors.Vocab at 0x7fb61259a550>,
#  'vampyres': <gensim.models.keyedvectors.Vocab at 0x7fb6124d4a58>,
#  'explained': <gensim.models.keyedvectors.Vocab at 0x7fb612af1da0>,
#  'ailment': <gensim.models.keyedvectors.Vocab at 0x7fb6124e5e48>,
#  'murmur': <gensim.models.keyedvectors.Vocab at 0x7fb6123bc3c8>,
#  'runaway': <gensim.models.keyedvectors.Vocab at 0x7fb6129e4cc0>,
#  'betterin': <gensim.models.keyedvectors.Vocab at 0x7fb612269550>,
#  'action:': <gensim.models.keyedvectors.Vocab at 0x7fb612132748>,
#  'discloses': <gensim.models.keyedvectors.Vocab at 0x7fb612632c18>,
#  'chilling': <gensim.models.keyedvectors.Vocab at 0x7fb612ac2710>,
#  'obscures': <gensim.models.keyedvectors.Vocab at 0x7fb612193e48>,
#  'jealously': <gensim.models.keyedvectors.Vocab at 0x7fb611dce860>,
#  'intention': <gensim.models.keyedvectors.Vocab at 0x7fb612ad9780>,
#  'warranting': <gensim.models.keyedvectors.Vocab at 0x7fb611dfc710>,
#  'translated': <gensim.models.keyedvectors.Vocab at 0x7fb612a50470>,
#  'anchor': <gensim.models.keyedvectors.Vocab at 0x7fb612962c18>,
#  'ovens': <gensim.models.keyedvectors.Vocab at 0x7fb611bc2240>,
#  'duel': <gensim.models.keyedvectors.Vocab at 0x7fb6129eb438>,
#  'speechless': <gensim.models.keyedvectors.Vocab at 0x7fb6128fabe0>,
#  'pathologically': <gensim.models.keyedvectors.Vocab at 0x7fb6121de240>,
#  'lowery': <gensim.models.keyedvectors.Vocab at 0x7fb6122b5358>,
#  'newhart': <gensim.models.keyedvectors.Vocab at 0x7fb6128581d0>,
#  'impostor': <gensim.models.keyedvectors.Vocab at 0x7fb6125cd198>,
#  'spontaneously': <gensim.models.keyedvectors.Vocab at 0x7fb6127bfb38>,
#  'terminators': <gensim.models.keyedvectors.Vocab at 0x7fb61246dac8>,
#  'winner': <gensim.models.keyedvectors.Vocab at 0x7fb612b1c7b8>,
#  'darden': <gensim.models.keyedvectors.Vocab at 0x7fb611d93400>,
#  'refrained': <gensim.models.keyedvectors.Vocab at 0x7fb6122a76d8>,
#  'charleys': <gensim.models.keyedvectors.Vocab at 0x7fb61240b400>,
#  'humorist': <gensim.models.keyedvectors.Vocab at 0x7fb612484470>,
#  'hellbent': <gensim.models.keyedvectors.Vocab at 0x7fb612739470>,
#  'succession': <gensim.models.keyedvectors.Vocab at 0x7fb61292a780>,
#  'roundly': <gensim.models.keyedvectors.Vocab at 0x7fb612402630>,
#  'swerve': <gensim.models.keyedvectors.Vocab at 0x7fb611be0470>,
#  'parker': <gensim.models.keyedvectors.Vocab at 0x7fb612aabd68>,
#  'revert': <gensim.models.keyedvectors.Vocab at 0x7fb6126e6f28>,
#  'buttons': <gensim.models.keyedvectors.Vocab at 0x7fb612984cf8>,
#  'dairy': <gensim.models.keyedvectors.Vocab at 0x7fb612671898>,
#  'reviewer': <gensim.models.keyedvectors.Vocab at 0x7fb612b0f240>,
#  'disappointedits': <gensim.models.keyedvectors.Vocab at 0x7fb611d10e10>,
#  'virgil': <gensim.models.keyedvectors.Vocab at 0x7fb61295d828>,
#  'squint': <gensim.models.keyedvectors.Vocab at 0x7fb612333da0>,
#  'unimaginable': <gensim.models.keyedvectors.Vocab at 0x7fb61279dc50>,
#  'jl': <gensim.models.keyedvectors.Vocab at 0x7fb611d04b38>,
#  'greystoke': <gensim.models.keyedvectors.Vocab at 0x7fb612269198>,
#  'beijing': <gensim.models.keyedvectors.Vocab at 0x7fb61279a860>,
#  'cruddy': <gensim.models.keyedvectors.Vocab at 0x7fb612658b00>,
#  'hilley': <gensim.models.keyedvectors.Vocab at 0x7fb6121c5b70>,
#  'lbs': <gensim.models.keyedvectors.Vocab at 0x7fb612523470>,
#  'vint': <gensim.models.keyedvectors.Vocab at 0x7fb6121d1208>,
#  'quistis': <gensim.models.keyedvectors.Vocab at 0x7fb6122b09e8>,
#  'looping': <gensim.models.keyedvectors.Vocab at 0x7fb6122a4780>,
#  'hooves': <gensim.models.keyedvectors.Vocab at 0x7fb611dcb438>,
#  'lightweight': <gensim.models.keyedvectors.Vocab at 0x7fb61293d2b0>,
#  '*spoiler': <gensim.models.keyedvectors.Vocab at 0x7fb61240d048>,
#  'milos': <gensim.models.keyedvectors.Vocab at 0x7fb6125ac748>,
#  'cheesier': <gensim.models.keyedvectors.Vocab at 0x7fb61265b0b8>,
#  'drame': <gensim.models.keyedvectors.Vocab at 0x7fb611c5af98>,
#  'imperious': <gensim.models.keyedvectors.Vocab at 0x7fb612512c88>,
#  'segura': <gensim.models.keyedvectors.Vocab at 0x7fb611df0898>,
#  'unsurprisingly': <gensim.models.keyedvectors.Vocab at 0x7fb612869470>,
#  'depravity': <gensim.models.keyedvectors.Vocab at 0x7fb6128cee80>,
#  'tether': <gensim.models.keyedvectors.Vocab at 0x7fb611c5d320>,
#  'whys': <gensim.models.keyedvectors.Vocab at 0x7fb6126211d0>,
#  'karate': <gensim.models.keyedvectors.Vocab at 0x7fb612a65b00>,
#  'benighted': <gensim.models.keyedvectors.Vocab at 0x7fb611c5a6a0>,
#  'incongruously': <gensim.models.keyedvectors.Vocab at 0x7fb611bf1160>,
#  'scenesand': <gensim.models.keyedvectors.Vocab at 0x7fb611c8d7b8>,
#  'words:': <gensim.models.keyedvectors.Vocab at 0x7fb6128c4a58>,
#  'overconfident': <gensim.models.keyedvectors.Vocab at 0x7fb6121dcac8>,
#  'locals': <gensim.models.keyedvectors.Vocab at 0x7fb612a46710>,
#  'retarded': <gensim.models.keyedvectors.Vocab at 0x7fb612abde48>,
#  'hard': <gensim.models.keyedvectors.Vocab at 0x7fb615866d30>,
#  'proverb': <gensim.models.keyedvectors.Vocab at 0x7fb6123ca780>,
#  'mishap': <gensim.models.keyedvectors.Vocab at 0x7fb6127a6cc0>,
#  'tic': <gensim.models.keyedvectors.Vocab at 0x7fb61214f9e8>,
#  'impede': <gensim.models.keyedvectors.Vocab at 0x7fb6121c75f8>,
#  'amos': <gensim.models.keyedvectors.Vocab at 0x7fb6128c4c50>,
#  'loveit': <gensim.models.keyedvectors.Vocab at 0x7fb611dd1cc0>,
#  'digital': <gensim.models.keyedvectors.Vocab at 0x7fb612ad59e8>,
#  'resoundingly': <gensim.models.keyedvectors.Vocab at 0x7fb612395710>,
#  'popeye': <gensim.models.keyedvectors.Vocab at 0x7fb6127809e8>,
#  'gadget': <gensim.models.keyedvectors.Vocab at 0x7fb6129d1e80>,
#  'goauld': <gensim.models.keyedvectors.Vocab at 0x7fb6125127b8>,
#  'priesthood': <gensim.models.keyedvectors.Vocab at 0x7fb611de5be0>,
#  'lightheartedness': <gensim.models.keyedvectors.Vocab at 0x7fb611cb9eb8>,
#  'hudsucker': <gensim.models.keyedvectors.Vocab at 0x7fb611d6bd30>,
#  'excelent': <gensim.models.keyedvectors.Vocab at 0x7fb6123c20b8>,
#  'invincibility': <gensim.models.keyedvectors.Vocab at 0x7fb611b1e048>,
#  'arguing': <gensim.models.keyedvectors.Vocab at 0x7fb6129c4278>,
#  'matches': <gensim.models.keyedvectors.Vocab at 0x7fb612aa3908>,
#  'pioneered': <gensim.models.keyedvectors.Vocab at 0x7fb612539f60>,
#  'fending': <gensim.models.keyedvectors.Vocab at 0x7fb61239d550>,
#  'blazing': <gensim.models.keyedvectors.Vocab at 0x7fb61299cc50>,
#  'miracle': <gensim.models.keyedvectors.Vocab at 0x7fb612aa55f8>,
#  'counting': <gensim.models.keyedvectors.Vocab at 0x7fb6129b4c50>,
#  'sowell': <gensim.models.keyedvectors.Vocab at 0x7fb611af19b0>,
#  'shui': <gensim.models.keyedvectors.Vocab at 0x7fb612249cf8>,
#  'learning': <gensim.models.keyedvectors.Vocab at 0x7fb612b28940>,
#  'p**s': <gensim.models.keyedvectors.Vocab at 0x7fb611c2c710>,
#  'immortal': <gensim.models.keyedvectors.Vocab at 0x7fb612a68f28>,
#  'extensively': <gensim.models.keyedvectors.Vocab at 0x7fb612731390>,
#  'skit': <gensim.models.keyedvectors.Vocab at 0x7fb6129bc630>,
#  'craigs': <gensim.models.keyedvectors.Vocab at 0x7fb6125c25c0>,
#  'apu': <gensim.models.keyedvectors.Vocab at 0x7fb612144f60>,
#  'whit': <gensim.models.keyedvectors.Vocab at 0x7fb6129243c8>,
#  'wonderous': <gensim.models.keyedvectors.Vocab at 0x7fb61219c828>,
#  'fake-looking': <gensim.models.keyedvectors.Vocab at 0x7fb612424c18>,
#  'tenuous': <gensim.models.keyedvectors.Vocab at 0x7fb612794b70>,
#  'schlesinger': <gensim.models.keyedvectors.Vocab at 0x7fb612650860>,
#  'mammy': <gensim.models.keyedvectors.Vocab at 0x7fb612689ba8>,
#  'cheapies': <gensim.models.keyedvectors.Vocab at 0x7fb612444048>,
#  'nets': <gensim.models.keyedvectors.Vocab at 0x7fb611b7d9b0>,
#  'testicle': <gensim.models.keyedvectors.Vocab at 0x7fb611c03d30>,
#  'compensations': <gensim.models.keyedvectors.Vocab at 0x7fb612484cc0>,
#  'amazon': <gensim.models.keyedvectors.Vocab at 0x7fb612a33748>,
#  'vinod': <gensim.models.keyedvectors.Vocab at 0x7fb6127c7c18>,
#  'viewingthe': <gensim.models.keyedvectors.Vocab at 0x7fb611abc668>,
#  'parasites': <gensim.models.keyedvectors.Vocab at 0x7fb6127dd3c8>,
#  'screen': <gensim.models.keyedvectors.Vocab at 0x7fb615867828>,
#  'proved': <gensim.models.keyedvectors.Vocab at 0x7fb612b006d8>,
#  'crash-lands': <gensim.models.keyedvectors.Vocab at 0x7fb611c13c88>,
#  'viagra': <gensim.models.keyedvectors.Vocab at 0x7fb612249588>,
#  'fools': <gensim.models.keyedvectors.Vocab at 0x7fb612a58cc0>,
#  'miserablythe': <gensim.models.keyedvectors.Vocab at 0x7fb611dbc550>,
#  'moogs': <gensim.models.keyedvectors.Vocab at 0x7fb611c92f98>,
#  'awfultitle': <gensim.models.keyedvectors.Vocab at 0x7fb611d50a58>,
#  'timmy': <gensim.models.keyedvectors.Vocab at 0x7fb6128c47f0>,
#  'lamb': <gensim.models.keyedvectors.Vocab at 0x7fb61281dc88>,
#  'glum': <gensim.models.keyedvectors.Vocab at 0x7fb6125fa5c0>,
#  'co-ed': <gensim.models.keyedvectors.Vocab at 0x7fb61256df28>,
#  'lita': <gensim.models.keyedvectors.Vocab at 0x7fb61243f668>,
#  'argues': <gensim.models.keyedvectors.Vocab at 0x7fb61289eb70>,
#  'sunburn': <gensim.models.keyedvectors.Vocab at 0x7fb611b83390>,
#  'herschell': <gensim.models.keyedvectors.Vocab at 0x7fb612647128>,
#  'light-years': <gensim.models.keyedvectors.Vocab at 0x7fb61247c5c0>,
#  'midsomer': <gensim.models.keyedvectors.Vocab at 0x7fb612346390>,
#  'dodger': <gensim.models.keyedvectors.Vocab at 0x7fb612729dd8>,
#  'those': <gensim.models.keyedvectors.Vocab at 0x7fb615860b70>,
#  'epitomize': <gensim.models.keyedvectors.Vocab at 0x7fb611af4208>,
#  'prevailed': <gensim.models.keyedvectors.Vocab at 0x7fb612557a20>,
#  'witt': <gensim.models.keyedvectors.Vocab at 0x7fb612410dd8>,
#  'party': <gensim.models.keyedvectors.Vocab at 0x7fb612b41908>,
#  'xenophobic': <gensim.models.keyedvectors.Vocab at 0x7fb612307940>,
#  'ill-at-ease': <gensim.models.keyedvectors.Vocab at 0x7fb612260438>,
#  'nsa': <gensim.models.keyedvectors.Vocab at 0x7fb6126cd748>,
#  'inventor': <gensim.models.keyedvectors.Vocab at 0x7fb6129224e0>,
#  'confound': <gensim.models.keyedvectors.Vocab at 0x7fb611dce4e0>,
#  'hisher': <gensim.models.keyedvectors.Vocab at 0x7fb61299e198>,
#  'hip-hop': <gensim.models.keyedvectors.Vocab at 0x7fb612979278>,
#  'undistinguished': <gensim.models.keyedvectors.Vocab at 0x7fb6125d67b8>,
#  'tracys': <gensim.models.keyedvectors.Vocab at 0x7fb61256d1d0>,
#  'lush': <gensim.models.keyedvectors.Vocab at 0x7fb6129ed3c8>,
#  'papier-mache': <gensim.models.keyedvectors.Vocab at 0x7fb61234ce48>,
#  'cherokee': <gensim.models.keyedvectors.Vocab at 0x7fb6125186d8>,
#  'plains': <gensim.models.keyedvectors.Vocab at 0x7fb6127b4048>,
#  'added': <gensim.models.keyedvectors.Vocab at 0x7fb612b50cf8>,
#  'teaming': <gensim.models.keyedvectors.Vocab at 0x7fb612906f28>,
#  'airmen': <gensim.models.keyedvectors.Vocab at 0x7fb612523fd0>,
#  '+-': <gensim.models.keyedvectors.Vocab at 0x7fb611cc1ef0>,
#  'stern': <gensim.models.keyedvectors.Vocab at 0x7fb6129fd908>,
#  'dark;': <gensim.models.keyedvectors.Vocab at 0x7fb612193e10>,
#  'diaries': <gensim.models.keyedvectors.Vocab at 0x7fb61296f588>,
#  'adrians': <gensim.models.keyedvectors.Vocab at 0x7fb61225de48>,
#  'classicthe': <gensim.models.keyedvectors.Vocab at 0x7fb612431ac8>,
#  'unsexy': <gensim.models.keyedvectors.Vocab at 0x7fb61238f2b0>,
#  'mahogany': <gensim.models.keyedvectors.Vocab at 0x7fb612279c18>,
#  'jonny': <gensim.models.keyedvectors.Vocab at 0x7fb61262ada0>,
#  'jacky': <gensim.models.keyedvectors.Vocab at 0x7fb612478a58>,
#  'tourist': <gensim.models.keyedvectors.Vocab at 0x7fb6129b7940>,
# ...
#  'geno': <gensim.models.keyedvectors.Vocab at 0x7fb611d440f0>,
#  'norma': <gensim.models.keyedvectors.Vocab at 0x7fb612aa3978>,
#  'brick': <gensim.models.keyedvectors.Vocab at 0x7fb6129ce2b0>,
#  'demmes': <gensim.models.keyedvectors.Vocab at 0x7fb6123b33c8>,
#  'teresas': <gensim.models.keyedvectors.Vocab at 0x7fb6121ce470>,
#  'thymian': <gensim.models.keyedvectors.Vocab at 0x7fb611db3320>,
#  'callaway': <gensim.models.keyedvectors.Vocab at 0x7fb6124b0c50>,
#  'buckmans': <gensim.models.keyedvectors.Vocab at 0x7fb611bc8c50>,
#  'bhai': <gensim.models.keyedvectors.Vocab at 0x7fb6123c8ac8>,
#  'organism': <gensim.models.keyedvectors.Vocab at 0x7fb6123386a0>,
#  'debuts': <gensim.models.keyedvectors.Vocab at 0x7fb6125970b8>,
#  'torpid': <gensim.models.keyedvectors.Vocab at 0x7fb6121a5e80>,
#  'denis': <gensim.models.keyedvectors.Vocab at 0x7fb6129a56a0>,
#  'frisson': <gensim.models.keyedvectors.Vocab at 0x7fb61239aef0>,
#  'dip': <gensim.models.keyedvectors.Vocab at 0x7fb61272e438>,
#  'degrade': <gensim.models.keyedvectors.Vocab at 0x7fb6126d6780>,
#  'over-reacting': <gensim.models.keyedvectors.Vocab at 0x7fb611b15550>,
#  'dehavillands': <gensim.models.keyedvectors.Vocab at 0x7fb611c40cc0>,
#  'lookalike': <gensim.models.keyedvectors.Vocab at 0x7fb6128a4eb8>,
#  'foolish': <gensim.models.keyedvectors.Vocab at 0x7fb612a651d0>,
#  'has-been': <gensim.models.keyedvectors.Vocab at 0x7fb6127b9908>,
#  '~': <gensim.models.keyedvectors.Vocab at 0x7fb6129eb860>,
#  'darlings': <gensim.models.keyedvectors.Vocab at 0x7fb61252ea58>,
#  'pamelas': <gensim.models.keyedvectors.Vocab at 0x7fb611afd780>,
#  'lui': <gensim.models.keyedvectors.Vocab at 0x7fb612525fd0>,
#  'hunchback': <gensim.models.keyedvectors.Vocab at 0x7fb6127bfa58>,
#  'pristine': <gensim.models.keyedvectors.Vocab at 0x7fb612872588>,
#  'ai': <gensim.models.keyedvectors.Vocab at 0x7fb6128aad68>,
#  'mjh': <gensim.models.keyedvectors.Vocab at 0x7fb611dea518>,
#  'pear-shaped': <gensim.models.keyedvectors.Vocab at 0x7fb611b71128>,
#  'emotions:': <gensim.models.keyedvectors.Vocab at 0x7fb61229f208>,
#  'noir': <gensim.models.keyedvectors.Vocab at 0x7fb612b674a8>,
#  'attempt': <gensim.models.keyedvectors.Vocab at 0x7fb615877630>,
#  'strays': <gensim.models.keyedvectors.Vocab at 0x7fb6127c1358>,
#  'shotsthe': <gensim.models.keyedvectors.Vocab at 0x7fb612346550>,
#  'alanna': <gensim.models.keyedvectors.Vocab at 0x7fb6121e5ef0>,
#  'ascent': <gensim.models.keyedvectors.Vocab at 0x7fb612331f60>,
#  'spiffy': <gensim.models.keyedvectors.Vocab at 0x7fb6121d62b0>,
#  'bijou': <gensim.models.keyedvectors.Vocab at 0x7fb612523cc0>,
#  'baumann': <gensim.models.keyedvectors.Vocab at 0x7fb61238d438>,
#  'cinemagic': <gensim.models.keyedvectors.Vocab at 0x7fb61217fbe0>,
#  'anansa': <gensim.models.keyedvectors.Vocab at 0x7fb6122f3f98>,
#  'creepy': <gensim.models.keyedvectors.Vocab at 0x7fb612b419e8>,
#  'treacle': <gensim.models.keyedvectors.Vocab at 0x7fb611dae240>,
#  'advocate': <gensim.models.keyedvectors.Vocab at 0x7fb61282f438>,
#  'misfortune': <gensim.models.keyedvectors.Vocab at 0x7fb6129f8b70>,
#  'chupacabra': <gensim.models.keyedvectors.Vocab at 0x7fb611aadb00>,
#  'farms': <gensim.models.keyedvectors.Vocab at 0x7fb612605278>,
#  'screws': <gensim.models.keyedvectors.Vocab at 0x7fb6128e7a20>,
#  'rudeness': <gensim.models.keyedvectors.Vocab at 0x7fb6123e14a8>,
#  'lanterns': <gensim.models.keyedvectors.Vocab at 0x7fb611e1c0b8>,
#  'recompense': <gensim.models.keyedvectors.Vocab at 0x7fb611bcd828>,
#  'initially': <gensim.models.keyedvectors.Vocab at 0x7fb612b1ca58>,
#  'prominent': <gensim.models.keyedvectors.Vocab at 0x7fb612a30cf8>,
#  'bethis': <gensim.models.keyedvectors.Vocab at 0x7fb612325dd8>,
#  'glands': <gensim.models.keyedvectors.Vocab at 0x7fb61226aba8>,
#  'olie': <gensim.models.keyedvectors.Vocab at 0x7fb611ac1048>,
#  'd:': <gensim.models.keyedvectors.Vocab at 0x7fb6125ff668>,
#  'sanjuro': <gensim.models.keyedvectors.Vocab at 0x7fb611b34278>,
#  'mcdonnells': <gensim.models.keyedvectors.Vocab at 0x7fb611ba8b00>,
#  'homing': <gensim.models.keyedvectors.Vocab at 0x7fb6121efcc0>,
#  'rulers': <gensim.models.keyedvectors.Vocab at 0x7fb612593668>,
#  'relevant': <gensim.models.keyedvectors.Vocab at 0x7fb612adc198>,
#  'bromley': <gensim.models.keyedvectors.Vocab at 0x7fb6122c70b8>,
#  'keatings': <gensim.models.keyedvectors.Vocab at 0x7fb611d2d9e8>,
#  'jolting': <gensim.models.keyedvectors.Vocab at 0x7fb6126bdda0>,
#  'plunging': <gensim.models.keyedvectors.Vocab at 0x7fb61269d7f0>,
#  'davids': <gensim.models.keyedvectors.Vocab at 0x7fb61292e278>,
#  'harvested': <gensim.models.keyedvectors.Vocab at 0x7fb612365518>,
#  'ingeniousness': <gensim.models.keyedvectors.Vocab at 0x7fb611b944a8>,
#  'confidently': <gensim.models.keyedvectors.Vocab at 0x7fb6126c7550>,
#  'oprah': <gensim.models.keyedvectors.Vocab at 0x7fb6128d49e8>,
#  'tisa': <gensim.models.keyedvectors.Vocab at 0x7fb61220f208>,
#  'marshal': <gensim.models.keyedvectors.Vocab at 0x7fb6128726a0>,
#  'sovetnik': <gensim.models.keyedvectors.Vocab at 0x7fb611b23b70>,
#  'marsden': <gensim.models.keyedvectors.Vocab at 0x7fb612733fd0>,
#  'inon': <gensim.models.keyedvectors.Vocab at 0x7fb611bec0b8>,
#  'serenades': <gensim.models.keyedvectors.Vocab at 0x7fb611b4e908>,
#  'hrishitaa': <gensim.models.keyedvectors.Vocab at 0x7fb611d1b080>,
#  'gumshoe': <gensim.models.keyedvectors.Vocab at 0x7fb612267400>,
#  'whites': <gensim.models.keyedvectors.Vocab at 0x7fb612a12438>,
#  'fluegel': <gensim.models.keyedvectors.Vocab at 0x7fb611d532b0>,
#  'accredited': <gensim.models.keyedvectors.Vocab at 0x7fb611b0c7f0>,
#  'spacecraft': <gensim.models.keyedvectors.Vocab at 0x7fb6128a7278>,
#  'chers': <gensim.models.keyedvectors.Vocab at 0x7fb6124ab5c0>,
#  'majors': <gensim.models.keyedvectors.Vocab at 0x7fb612891d30>,
#  'harmed': <gensim.models.keyedvectors.Vocab at 0x7fb6127cf278>,
#  'place:': <gensim.models.keyedvectors.Vocab at 0x7fb6125af588>,
#  'child-friendly': <gensim.models.keyedvectors.Vocab at 0x7fb611c87748>,
#  'focusing': <gensim.models.keyedvectors.Vocab at 0x7fb612a98be0>,
#  'southwestern': <gensim.models.keyedvectors.Vocab at 0x7fb6122e4160>,
#  'scale!': <gensim.models.keyedvectors.Vocab at 0x7fb611abca90>,
#  'networking': <gensim.models.keyedvectors.Vocab at 0x7fb611b48860>,
#  'makoto': <gensim.models.keyedvectors.Vocab at 0x7fb612144ac8>,
#  'kristen': <gensim.models.keyedvectors.Vocab at 0x7fb6128c4be0>,
#  'stylistic': <gensim.models.keyedvectors.Vocab at 0x7fb61298cc50>,
#  'allright': <gensim.models.keyedvectors.Vocab at 0x7fb611b968d0>,
#  'panther': <gensim.models.keyedvectors.Vocab at 0x7fb612a43470>,
#  'apartheid': <gensim.models.keyedvectors.Vocab at 0x7fb6127dd7f0>,
#  'likelihood': <gensim.models.keyedvectors.Vocab at 0x7fb6126d63c8>,
#  'touching': <gensim.models.keyedvectors.Vocab at 0x7fb612b550f0>,
#  'gene': <gensim.models.keyedvectors.Vocab at 0x7fb612b00860>,
#  'overview': <gensim.models.keyedvectors.Vocab at 0x7fb61276d748>,
#  '*in': <gensim.models.keyedvectors.Vocab at 0x7fb612201748>,
#  'kind!': <gensim.models.keyedvectors.Vocab at 0x7fb6121bc780>,
#  'aubrey': <gensim.models.keyedvectors.Vocab at 0x7fb6128f0320>,
#  'cutting-edge': <gensim.models.keyedvectors.Vocab at 0x7fb612572a20>,
#  'hanlon': <gensim.models.keyedvectors.Vocab at 0x7fb611d2a400>,
#  'meanders': <gensim.models.keyedvectors.Vocab at 0x7fb612903e10>,
#  'moments!': <gensim.models.keyedvectors.Vocab at 0x7fb61213b0b8>,
#  'todds': <gensim.models.keyedvectors.Vocab at 0x7fb612731a58>,
#  'notches': <gensim.models.keyedvectors.Vocab at 0x7fb612758080>,
#  'lengthening': <gensim.models.keyedvectors.Vocab at 0x7fb611b237b8>,
#  'swipe': <gensim.models.keyedvectors.Vocab at 0x7fb612554e10>,
#  'trunk': <gensim.models.keyedvectors.Vocab at 0x7fb6128eae80>,
#  'low-point': <gensim.models.keyedvectors.Vocab at 0x7fb612338390>,
#  'that:': <gensim.models.keyedvectors.Vocab at 0x7fb6129627b8>,
#  'venture': <gensim.models.keyedvectors.Vocab at 0x7fb612a58470>,
#  'semi-autobiographical': <gensim.models.keyedvectors.Vocab at 0x7fb612531160>,
#  'bastardization': <gensim.models.keyedvectors.Vocab at 0x7fb612252be0>,
#  'inkheart': <gensim.models.keyedvectors.Vocab at 0x7fb611da4a90>,
#  'mameha': <gensim.models.keyedvectors.Vocab at 0x7fb611c40f98>,
#  'mercifully': <gensim.models.keyedvectors.Vocab at 0x7fb612957860>,
#  'ft': <gensim.models.keyedvectors.Vocab at 0x7fb6126bf2e8>,
#  'itokay': <gensim.models.keyedvectors.Vocab at 0x7fb611d04a20>,
#  'presidio': <gensim.models.keyedvectors.Vocab at 0x7fb611c82da0>,
#  'cradle': <gensim.models.keyedvectors.Vocab at 0x7fb6128a1080>,
#  'stretched': <gensim.models.keyedvectors.Vocab at 0x7fb612a46d68>,
#  'scenery;': <gensim.models.keyedvectors.Vocab at 0x7fb611ded780>,
#  'grapples': <gensim.models.keyedvectors.Vocab at 0x7fb611b577b8>,
#  'farnsworths': <gensim.models.keyedvectors.Vocab at 0x7fb611cfc198>,
#  'carells': <gensim.models.keyedvectors.Vocab at 0x7fb6123920f0>,
#  '10-year-old': <gensim.models.keyedvectors.Vocab at 0x7fb612694048>,
#  'muchif': <gensim.models.keyedvectors.Vocab at 0x7fb6122d3550>,
#  'airplanes': <gensim.models.keyedvectors.Vocab at 0x7fb6128dff98>,
#  'crushing': <gensim.models.keyedvectors.Vocab at 0x7fb6128cc630>,
#  'witnesses': <gensim.models.keyedvectors.Vocab at 0x7fb612aa5f28>,
#  'dementia': <gensim.models.keyedvectors.Vocab at 0x7fb6126d1390>,
#  'norbit': <gensim.models.keyedvectors.Vocab at 0x7fb612175a58>,
#  'bal': <gensim.models.keyedvectors.Vocab at 0x7fb611d9cba8>,
#  'grover': <gensim.models.keyedvectors.Vocab at 0x7fb61281a518>,
#  'belted': <gensim.models.keyedvectors.Vocab at 0x7fb612495198>,
#  'stiller': <gensim.models.keyedvectors.Vocab at 0x7fb612a4a0f0>,
#  'self-absorption': <gensim.models.keyedvectors.Vocab at 0x7fb61232ea20>,
#  'heckle': <gensim.models.keyedvectors.Vocab at 0x7fb6121cef60>,
#  'mclane': <gensim.models.keyedvectors.Vocab at 0x7fb611ca7278>,
#  '$300': <gensim.models.keyedvectors.Vocab at 0x7fb6124878d0>,
#  'booking': <gensim.models.keyedvectors.Vocab at 0x7fb612263780>,
#  'coherence': <gensim.models.keyedvectors.Vocab at 0x7fb61294a4e0>,
#  'logic': <gensim.models.keyedvectors.Vocab at 0x7fb612b080f0>,
#  'trini': <gensim.models.keyedvectors.Vocab at 0x7fb612608cc0>,
#  'adonis': <gensim.models.keyedvectors.Vocab at 0x7fb611d50e48>,
#  'thornton': <gensim.models.keyedvectors.Vocab at 0x7fb6128fd320>,
#  '1998': <gensim.models.keyedvectors.Vocab at 0x7fb612a4db70>,
#  'much;': <gensim.models.keyedvectors.Vocab at 0x7fb6125203c8>,
#  'gutsy': <gensim.models.keyedvectors.Vocab at 0x7fb6127a0e48>,
#  'mid-sentence': <gensim.models.keyedvectors.Vocab at 0x7fb611ae9208>,
#  'smothering': <gensim.models.keyedvectors.Vocab at 0x7fb6123b0908>,
#  'ltr': <gensim.models.keyedvectors.Vocab at 0x7fb611b6ff28>,
#  'tripplehorn': <gensim.models.keyedvectors.Vocab at 0x7fb6122ad860>,
#  'daughter;': <gensim.models.keyedvectors.Vocab at 0x7fb612450780>,
#  'stressing': <gensim.models.keyedvectors.Vocab at 0x7fb61250a780>,
#  'culturei': <gensim.models.keyedvectors.Vocab at 0x7fb611acf278>,
#  'actorsactresses': <gensim.models.keyedvectors.Vocab at 0x7fb61294a198>,
#  'cyborg': <gensim.models.keyedvectors.Vocab at 0x7fb6129c2da0>,
#  're-enters': <gensim.models.keyedvectors.Vocab at 0x7fb61229b630>,
#  '14-year': <gensim.models.keyedvectors.Vocab at 0x7fb612168470>,
#  'glance': <gensim.models.keyedvectors.Vocab at 0x7fb6129fbe10>,
#  'realisticthe': <gensim.models.keyedvectors.Vocab at 0x7fb611d70550>,
#  'vet': <gensim.models.keyedvectors.Vocab at 0x7fb6129ce7b8>,
#  'reveals': <gensim.models.keyedvectors.Vocab at 0x7fb612aab198>,
#  'astral': <gensim.models.keyedvectors.Vocab at 0x7fb61242c588>,
#  'hooded': <gensim.models.keyedvectors.Vocab at 0x7fb6126c2748>,
#  'asha': <gensim.models.keyedvectors.Vocab at 0x7fb6126a7f98>,
#  'overstays': <gensim.models.keyedvectors.Vocab at 0x7fb6121d3208>,
#  'fricker': <gensim.models.keyedvectors.Vocab at 0x7fb6126f1e48>,
#  'degrees': <gensim.models.keyedvectors.Vocab at 0x7fb6129c2828>,
#  'recognizable': <gensim.models.keyedvectors.Vocab at 0x7fb612a43208>,
#  'debilitating': <gensim.models.keyedvectors.Vocab at 0x7fb6123ebb38>,
#  'shonali': <gensim.models.keyedvectors.Vocab at 0x7fb611d8eb38>,
#  'disheartened': <gensim.models.keyedvectors.Vocab at 0x7fb61213b908>,
#  'choir': <gensim.models.keyedvectors.Vocab at 0x7fb612952c18>,
#  'popaul': <gensim.models.keyedvectors.Vocab at 0x7fb6124d4f28>,
#  'mannix': <gensim.models.keyedvectors.Vocab at 0x7fb611d70b38>,
#  'citizenship': <gensim.models.keyedvectors.Vocab at 0x7fb612241710>,
#  'outcome': <gensim.models.keyedvectors.Vocab at 0x7fb612a6be80>,
#  'allergies': <gensim.models.keyedvectors.Vocab at 0x7fb611df0d68>,
#  'robot-like': <gensim.models.keyedvectors.Vocab at 0x7fb611d09588>,
#  'clichéd': <gensim.models.keyedvectors.Vocab at 0x7fb612b1c908>,
#  'fiercest': <gensim.models.keyedvectors.Vocab at 0x7fb611b3c4e0>,
#  'hours!': <gensim.models.keyedvectors.Vocab at 0x7fb6126c5208>,
#  'wedding': <gensim.models.keyedvectors.Vocab at 0x7fb612af3dd8>,
#  'sprinkled': <gensim.models.keyedvectors.Vocab at 0x7fb61291c7f0>,
#  'fiddling': <gensim.models.keyedvectors.Vocab at 0x7fb612220cc0>,
#  'woolf': <gensim.models.keyedvectors.Vocab at 0x7fb612624b38>,
#  'blackwood': <gensim.models.keyedvectors.Vocab at 0x7fb612528be0>,
#  'arte': <gensim.models.keyedvectors.Vocab at 0x7fb612416748>,
#  'chosen': <gensim.models.keyedvectors.Vocab at 0x7fb612b11940>,
#  'converse': <gensim.models.keyedvectors.Vocab at 0x7fb612736b70>,
#  'bernsen': <gensim.models.keyedvectors.Vocab at 0x7fb61282c828>,
#  'nishi': <gensim.models.keyedvectors.Vocab at 0x7fb611cf0a58>,
#  'messthis': <gensim.models.keyedvectors.Vocab at 0x7fb6121f5198>,
#  'scraped': <gensim.models.keyedvectors.Vocab at 0x7fb6126dc400>,
#  'schaeffer': <gensim.models.keyedvectors.Vocab at 0x7fb612343a20>,
#  'hipsters': <gensim.models.keyedvectors.Vocab at 0x7fb612495b70>,
#  'heartfelt': <gensim.models.keyedvectors.Vocab at 0x7fb612a5a9e8>,
#  'executing': <gensim.models.keyedvectors.Vocab at 0x7fb612768978>,
#  'sellars': <gensim.models.keyedvectors.Vocab at 0x7fb612373630>,
#  'basque': <gensim.models.keyedvectors.Vocab at 0x7fb6122fb898>,
#  'misunderstanding': <gensim.models.keyedvectors.Vocab at 0x7fb6129119b0>,
#  'g-unit': <gensim.models.keyedvectors.Vocab at 0x7fb612288e80>,
#  'vaporize': <gensim.models.keyedvectors.Vocab at 0x7fb611c6f2b0>,
#  'bowser': <gensim.models.keyedvectors.Vocab at 0x7fb612237c50>,
#  'torrential': <gensim.models.keyedvectors.Vocab at 0x7fb61248ccc0>,
#  'efficient': <gensim.models.keyedvectors.Vocab at 0x7fb61298a978>,
#  'poorly': <gensim.models.keyedvectors.Vocab at 0x7fb612b38ac8>,
#  'lol': <gensim.models.keyedvectors.Vocab at 0x7fb612a3bb70>,
#  'fang': <gensim.models.keyedvectors.Vocab at 0x7fb612630b70>,
#  'federation': <gensim.models.keyedvectors.Vocab at 0x7fb61283ac88>,
#  'lowes': <gensim.models.keyedvectors.Vocab at 0x7fb6124e0550>,
#  'obey': <gensim.models.keyedvectors.Vocab at 0x7fb61281d080>,
#  'begrudging': <gensim.models.keyedvectors.Vocab at 0x7fb611c32278>,
#  'chore': <gensim.models.keyedvectors.Vocab at 0x7fb612950588>,
#  'sanitized': <gensim.models.keyedvectors.Vocab at 0x7fb6127e5208>,
#  'weaknesses:': <gensim.models.keyedvectors.Vocab at 0x7fb611b0a9b0>,
#  'lulled': <gensim.models.keyedvectors.Vocab at 0x7fb6122adf28>,
#  'abhorred': <gensim.models.keyedvectors.Vocab at 0x7fb611acfda0>,
#  'them': <gensim.models.keyedvectors.Vocab at 0x7fb61585d6d8>,
#  'shoulder': <gensim.models.keyedvectors.Vocab at 0x7fb612a65c18>,
#  'straightened': <gensim.models.keyedvectors.Vocab at 0x7fb61247c908>,
#  'mortgage': <gensim.models.keyedvectors.Vocab at 0x7fb6126ffb38>,
#  'positioned': <gensim.models.keyedvectors.Vocab at 0x7fb61263ec18>,
#  'agile': <gensim.models.keyedvectors.Vocab at 0x7fb612627c50>,
#  'displaying': <gensim.models.keyedvectors.Vocab at 0x7fb6129c2198>,
#  'inside': <gensim.models.keyedvectors.Vocab at 0x7fb612b40f28>,
#  'centurythis': <gensim.models.keyedvectors.Vocab at 0x7fb611b07780>,
#  'tentative': <gensim.models.keyedvectors.Vocab at 0x7fb61275b1d0>,
#  'hardship': <gensim.models.keyedvectors.Vocab at 0x7fb61289e780>,
#  'gadgets': <gensim.models.keyedvectors.Vocab at 0x7fb612948908>,
#  'pants': <gensim.models.keyedvectors.Vocab at 0x7fb612a81f60>,
#  ...}

# %%
logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.INFO)

# %%
sentences = word2vec.LineSentence("/data4T/share/jiangxinyang848/textClassifier/data/preProcess/wordEmbdiing.txt")
a = list(sentences)
len(a)
# Out:
# 75000

# %%
model = gensim.models.Word2Vec(sentences, size=200, sg=1, iter=8)  
model.wv.save_word2vec_format("./word2Vec" + ".bin", binary=True)
# Out:
# 2018-12-26 14:04:33,186 : INFO : collecting all words and their counts
# 2018-12-26 14:04:33,188 : INFO : PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# 2018-12-26 14:04:33,661 : INFO : PROGRESS: at sentence #10000, processed 2284702 words, keeping 91864 word types
# 2018-12-26 14:04:34,147 : INFO : PROGRESS: at sentence #20000, processed 4604942 words, keeping 142355 word types
# 2018-12-26 14:04:34,649 : INFO : PROGRESS: at sentence #30000, processed 6919387 words, keeping 185591 word types
# 2018-12-26 14:04:35,130 : INFO : PROGRESS: at sentence #40000, processed 9207751 words, keeping 223091 word types
# 2018-12-26 14:04:35,618 : INFO : PROGRESS: at sentence #50000, processed 11507706 words, keeping 258152 word types
# 2018-12-26 14:04:36,121 : INFO : PROGRESS: at sentence #60000, processed 13819822 words, keeping 293504 word types
# 2018-12-26 14:04:36,606 : INFO : PROGRESS: at sentence #70000, processed 16108891 words, keeping 325418 word types
# 2018-12-26 14:04:36,859 : INFO : collected 340830 word types from a corpus of 17245942 raw words and 75000 sentences
# 2018-12-26 14:04:36,860 : INFO : Loading a fresh vocabulary
# 2018-12-26 14:04:37,498 : INFO : effective_min_count=5 retains 58733 unique words (17% of original 340830, drops 282097)
# 2018-12-26 14:04:37,499 : INFO : effective_min_count=5 leaves 16872183 word corpus (97% of original 17245942, drops 373759)
# 2018-12-26 14:04:37,662 : INFO : deleting the raw counts dictionary of 340830 items
# 2018-12-26 14:04:37,690 : INFO : sample=0.001 downsamples 45 most-common words
